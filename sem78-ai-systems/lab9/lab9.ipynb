# %% [markdown]
# * https://www.kaggle.com/competitions/playground-series-s5e2

# %%
import pandas as pd
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor

pd.set_option('future.no_silent_downcasting', True)

# %%
from zipfile import ZipFile

with ZipFile("backpack.zip") as bp:
    
    with bp.open("test.csv") as t:
        test_df = pd.read_csv(t)

    with bp.open("train.csv") as t:
        train_df = pd.read_csv(t)

    with bp.open("training_extra.csv") as t:
        training_extra_df = pd.read_csv(t)

# %%
train_df
# Out:
#             id         Brand Material    Size  Compartments  \
# 0            0      Jansport  Leather  Medium           7.0
# 1            1      Jansport   Canvas   Small          10.0
# 2            2  Under Armour  Leather   Small           2.0
# 3            3          Nike    Nylon   Small           8.0
# 4            4        Adidas   Canvas  Medium           1.0
# ...        ...           ...      ...     ...           ...
# 299995  299995        Adidas  Leather   Small           9.0
# 299996  299996      Jansport  Leather   Large           6.0
# 299997  299997          Puma   Canvas   Large           9.0
# 299998  299998        Adidas    Nylon   Small           1.0
# 299999  299999  Under Armour   Canvas   Small           2.0
#
#        Laptop Compartment Waterproof      Style  Color  Weight Capacity (kg)  \
# 0                     Yes         No       Tote  Black             11.611723
# 1                     Yes        Yes  Messenger  Green             27.078537
# 2                     Yes         No  Messenger    Red             16.643760
# 3                     Yes         No  Messenger  Green             12.937220
# 4                     Yes        Yes  Messenger  Green             17.749338
# ...                   ...        ...        ...    ...                   ...
# 299995                 No         No       Tote   Blue             12.730812
# 299996                 No        Yes       Tote   Blue             26.633182
# 299997                Yes        Yes   Backpack   Pink             11.898250
# 299998                 No        Yes       Tote   Pink              6.175738
# 299999                 No        Yes   Backpack  Black             18.568865
#
#             Price
# 0       112.15875
# 1        68.88056
# 2        39.17320
# 3        80.60793
# 4        86.02312
# ...           ...
# 299995  129.99749
# 299996   19.85819
# 299997  111.41364
# 299998  115.89080
# 299999   26.72762
#
# [300000 rows x 11 columns]

# %%
train_df.isna().sum()
# Out:
# id                         0
# Brand                   9705
# Material                8347
# Size                    6595
# Compartments               0
# Laptop Compartment      7444
# Waterproof              7050
# Style                   7970
# Color                   9950
# Weight Capacity (kg)     138
# Price                      0
# dtype: int64

# %%
def one_hot(_df: pd.DataFrame, cols: list) -> pd.DataFrame:
    df = _df.copy()
    df = df.join( [ pd.get_dummies(df[col]).astype(int) for col in cols ] )
    df = df.drop(cols, axis=1)
    return df


def fillna_mode(_df: pd.DataFrame, cols: list) -> pd.DataFrame:
    df = _df.copy()
    for col in cols:
        df[col] = df[col].fillna(df[col].mode()[0])
    return df


def fillna_mean(_df: pd.DataFrame, cols: list) -> pd.DataFrame:
    df = _df.copy()
    for col in cols:
        df[col] = df[col].fillna(df[col].mean())
    return df

def make_df(_df: pd.DataFrame) -> pd.DataFrame:
    df = _df.copy()

    df = fillna_mode(df, ["Laptop Compartment", "Waterproof", "Brand", "Material", "Size", "Style", "Color"])
    df = fillna_mean(df, ["Weight Capacity (kg)"])

    df["Laptop Compartment"] = df["Laptop Compartment"].replace({"No": False, "Yes": True}).astype(bool)
    df["Waterproof"] = df["Waterproof"].replace({"No": False, "Yes": True}).astype(bool)

    df = df.drop([
        "id"
    ], axis=1)

    # df["WeightCompartments"] = df["Weight Capacity (kg)"] * df["Compartments"]

    return df

def make_df_with_one_hot(_df: pd.DataFrame) -> pd.DataFrame:
    df = make_df(_df)

    df = one_hot(df, ["Brand", "Material", "Size", "Style", "Color"])

    return df

def get_xy(_df: pd.DataFrame, y_names: list) -> tuple[pd.DataFrame, pd.DataFrame]:
    df_x = _df.copy()

    df_y = df_x[y_names]
    df_x = df_x.drop(y_names, axis=1)

    return df_x, df_y

def normalize(_df: pd.DataFrame) -> pd.DataFrame:
    df = _df.copy()

    number_cols = [a for a, b in df.dtypes.items() if "float" in str(b) or "int" in str(b) ]

    df_number = df[number_cols]
    df_number = (df_number - df_number.min()) / (df_number.max() - df_number.min())
    df[number_cols] = df_number.astype("float64")

    
    cat_cols = [a for a, b in df.dtypes.items() if "float" not in str(b) and "int" not in str(b) and "bool" not in str(b) ]
    df[cat_cols] = df[cat_cols].astype("category")

    return df

# %%
# _train_df = make_df(train_df)
_train_df = make_df_with_one_hot(train_df)

train_x, train_y = get_xy(_train_df, ["Price"])
train_y.isna().sum()
# Out:
# Price    0
# dtype: int64

# %%
_train_df_n = normalize(_train_df)
train_x_n = normalize(train_x)
train_y_n = normalize(train_y)

# %%
# _train_df_n["Weight Capacity (kg)"] = pd.cut( _train_df_n["Weight Capacity (kg)"], 10, labels=False)

# %%
_train_df_n.corr() #.abs() > 0.01
# Out:
#                       Compartments  Laptop Compartment  Waterproof  \
# Compartments              1.000000           -0.003252   -0.004778
# Laptop Compartment       -0.003252            1.000000   -0.027695
# Waterproof               -0.004778           -0.027695    1.000000
# Weight Capacity (kg)      0.002541            0.003611    0.004568
# Price                    -0.000131           -0.001321   -0.003984
# Adidas                    0.002659           -0.003346   -0.002535
# Jansport                 -0.000860            0.000299   -0.001854
# Nike                      0.002752            0.001428    0.003989
# Puma                     -0.001719           -0.001750   -0.001004
# Under Armour             -0.002992            0.003552    0.001547
# Canvas                    0.005613           -0.003754   -0.000911
# Leather                  -0.005095           -0.002172    0.000486
# Nylon                    -0.002228            0.000941   -0.000065
# Polyester                 0.001726            0.004627    0.000439
# Large                     0.007656            0.001108   -0.000771
# Medium                   -0.005320           -0.001946    0.000475
# Small                    -0.002250            0.000896    0.000290
# Backpack                 -0.007422           -0.002890   -0.000410
# Messenger                 0.002203            0.005303    0.001428
# Tote                      0.005106           -0.002568   -0.001057
# Black                     0.001359           -0.003201    0.000007
# Blue                     -0.000073           -0.002203   -0.000136
# Gray                      0.000714            0.005435    0.002567
# Green                     0.000621            0.001852   -0.001988
# Pink                     -0.001178            0.000911    0.001611
# Red                      -0.001317           -0.003026   -0.002317
#
#                       Weight Capacity (kg)     Price    Adidas  Jansport  \
# Compartments                      0.002541 -0.000131  0.002659 -0.000860
# Laptop Compartment                0.003611 -0.001321 -0.003346  0.000299
# Waterproof                        0.004568 -0.003984 -0.002535 -0.001854
# Weight Capacity (kg)              1.000000  0.018013  0.001176 -0.001724
# Price                             0.018013  1.000000 -0.010527  0.004669
# Adidas                            0.001176 -0.010527  1.000000 -0.263975
# Jansport                         -0.001724  0.004669 -0.263975  1.000000
# Nike                             -0.000356 -0.001144 -0.267617 -0.233062
# Puma                             -0.005104  0.000464 -0.266110 -0.231750
# Under Armour                      0.005788  0.007238 -0.275255 -0.239715
# Canvas                           -0.010483  0.009644  0.002314 -0.002988
# Leather                           0.005105 -0.014190 -0.000276  0.002388
# Nylon                             0.000620 -0.005490 -0.005593  0.005359
# Polyester                         0.004242  0.009647  0.003344 -0.004501
# Large                             0.000166  0.004309 -0.000874 -0.000844
# Medium                            0.002433 -0.004437  0.002462  0.002046
# Small                            -0.002697  0.000233 -0.001671 -0.001270
# Backpack                         -0.001777 -0.000149 -0.001079  0.001374
# Messenger                         0.000442  0.000773  0.000793 -0.003768
# Tote                              0.001310 -0.000644  0.000257  0.002499
# Black                            -0.000687 -0.009833  0.002142 -0.000945
# Blue                             -0.000431  0.006670 -0.002014  0.002650
# Gray                              0.003910 -0.006427 -0.005333 -0.000832
# Green                            -0.001631  0.010628 -0.000212 -0.000815
# Pink                             -0.001701  0.003158  0.002053  0.001106
# Red                               0.000612 -0.004422  0.003305 -0.001295
#
#                           Nike      Puma  Under Armour  ...     Small  \
# Compartments          0.002752 -0.001719     -0.002992  ... -0.002250
# Laptop Compartment    0.001428 -0.001750      0.003552  ...  0.000896
# Waterproof            0.003989 -0.001004      0.001547  ...  0.000290
# Weight Capacity (kg) -0.000356 -0.005104      0.005788  ... -0.002697
# Price                -0.001144  0.000464      0.007238  ...  0.000233
# Adidas               -0.267617 -0.266110     -0.275255  ... -0.001671
# Jansport             -0.233062 -0.231750     -0.239715  ... -0.001270
# Nike                  1.000000 -0.234947     -0.243022  ...  0.001144
# Puma                 -0.234947  1.000000     -0.241653  ... -0.000204
# Under Armour         -0.243022 -0.241653      1.000000  ...  0.002078
# Canvas                0.004213 -0.004686      0.000916  ...  0.004795
# Leather               0.005280 -0.004938     -0.002389  ... -0.002159
# Nylon                -0.005349  0.003654      0.002363  ... -0.001513
# Polyester            -0.003876  0.005567     -0.000788  ... -0.000960
# Large                -0.002087  0.001394      0.002431  ... -0.468618
# Medium                0.000940 -0.001167     -0.004376  ... -0.503967
# Small                 0.001144 -0.000204      0.002078  ...  1.000000
# Backpack              0.005082 -0.002490     -0.002757  ...  0.004477
# Messenger            -0.002334  0.002442      0.002738  ...  0.000969
# Tote                 -0.002649 -0.000033     -0.000071  ... -0.005435
# Black                -0.000721 -0.002167      0.001490  ... -0.002591
# Blue                  0.000525 -0.001568      0.000565  ... -0.001847
# Gray                  0.001441  0.002414      0.002663  ... -0.001190
# Green                 0.001377  0.000386     -0.000714  ...  0.003542
# Pink                 -0.003035  0.002266     -0.002482  ... -0.002085
# Red                   0.000710 -0.001643     -0.001317  ...  0.004450
#
#                       Backpack  Messenger      Tote     Black      Blue  \
# Compartments         -0.007422   0.002203  0.005106  0.001359 -0.000073
# Green                -0.191901  1.000000 -0.217481 -0.184839
# Pink                 -0.228184 -0.217481  1.000000 -0.219786
# Red                  -0.193935 -0.184839 -0.219786  1.000000
#
# [26 rows x 26 columns]

# %%
_train_df2 = make_df_with_one_hot(training_extra_df)

train_x2, train_y2 = get_xy(_train_df2, ["Price"])

train_x_n2 = normalize(train_x2)
train_y_n2 = normalize(train_y2)

# %%
xgb = XGBRegressor(
    n_estimators=1000,
    # max_depth=6,
    learning_rate=0.01,
    n_jobs=-1,
    enable_categorical=True,
)

# %%
xgb.fit(train_x_n2, train_y_n2, eval_set=[(train_x_n, train_y_n)], verbose=True)
# Out:
# [0]	validation_0-rmse:0.28918
# [1]	validation_0-rmse:0.28917
# [2]	validation_0-rmse:0.28917
# [3]	validation_0-rmse:0.28917
# [4]	validation_0-rmse:0.28916
# [5]	validation_0-rmse:0.28916
# [6]	validation_0-rmse:0.28916
# [7]	validation_0-rmse:0.28915
# [8]	validation_0-rmse:0.28915
# [9]	validation_0-rmse:0.28915
# [10]	validation_0-rmse:0.28915
# [11]	validation_0-rmse:0.28914
# [12]	validation_0-rmse:0.28914
# [13]	validation_0-rmse:0.28914
# [14]	validation_0-rmse:0.28913
# [15]	validation_0-rmse:0.28913
# [16]	validation_0-rmse:0.28913
# [17]	validation_0-rmse:0.28913
# [18]	validation_0-rmse:0.28912
# [19]	validation_0-rmse:0.28912
# [20]	validation_0-rmse:0.28912
# [21]	validation_0-rmse:0.28912
# [22]	validation_0-rmse:0.28912
# [23]	validation_0-rmse:0.28911
# [24]	validation_0-rmse:0.28911
# [25]	validation_0-rmse:0.28911
# [26]	validation_0-rmse:0.28911
# [27]	validation_0-rmse:0.28911
# [28]	validation_0-rmse:0.28910
# [29]	validation_0-rmse:0.28910
# [30]	validation_0-rmse:0.28910
# [31]	validation_0-rmse:0.28910
# [32]	validation_0-rmse:0.28910
# [33]	validation_0-rmse:0.28909
# [34]	validation_0-rmse:0.28909
# [35]	validation_0-rmse:0.28909
# [36]	validation_0-rmse:0.28909
# [37]	validation_0-rmse:0.28909
# [38]	validation_0-rmse:0.28909
# [39]	validation_0-rmse:0.28908
# [40]	validation_0-rmse:0.28908
# [41]	validation_0-rmse:0.28908
# [42]	validation_0-rmse:0.28908
# [43]	validation_0-rmse:0.28908
# [44]	validation_0-rmse:0.28908
# [45]	validation_0-rmse:0.28907
# [46]	validation_0-rmse:0.28907
# [47]	validation_0-rmse:0.28907
# [48]	validation_0-rmse:0.28907
# [49]	validation_0-rmse:0.28907
# [50]	validation_0-rmse:0.28907
# [51]	validation_0-rmse:0.28907
# [52]	validation_0-rmse:0.28906
# [53]	validation_0-rmse:0.28906
# [54]	validation_0-rmse:0.28906
# [55]	validation_0-rmse:0.28906
# [56]	validation_0-rmse:0.28906
# [57]	validation_0-rmse:0.28906
# [58]	validation_0-rmse:0.28906
# [59]	validation_0-rmse:0.28906
# [60]	validation_0-rmse:0.28906
# [61]	validation_0-rmse:0.28905
# [62]	validation_0-rmse:0.28905
# [383]	validation_0-rmse:0.28896
# [384]	validation_0-rmse:0.28896
# [385]	validation_0-rmse:0.28896
# [386]	validation_0-rmse:0.28896
# [387]	validation_0-rmse:0.28896
# [388]	validation_0-rmse:0.28896
# [389]	validation_0-rmse:0.28896
# [390]	validation_0-rmse:0.28896
# [391]	validation_0-rmse:0.28896
# [392]	validation_0-rmse:0.28896
# [393]	validation_0-rmse:0.28896
# [394]	validation_0-rmse:0.28896
# [395]	validation_0-rmse:0.28896
# [396]	validation_0-rmse:0.28896
# [397]	validation_0-rmse:0.28896
# [398]	validation_0-rmse:0.28896
# [399]	validation_0-rmse:0.28896
# [400]	validation_0-rmse:0.28896
# [401]	validation_0-rmse:0.28896
# [402]	validation_0-rmse:0.28896
# [403]	validation_0-rmse:0.28896
# [404]	validation_0-rmse:0.28896
# [405]	validation_0-rmse:0.28896
# [406]	validation_0-rmse:0.28896
# [407]	validation_0-rmse:0.28896
# [408]	validation_0-rmse:0.28896
# [409]	validation_0-rmse:0.28896
# [410]	validation_0-rmse:0.28896
# [411]	validation_0-rmse:0.28896
# [412]	validation_0-rmse:0.28896
# [413]	validation_0-rmse:0.28896
# [414]	validation_0-rmse:0.28896
# [415]	validation_0-rmse:0.28896
# [416]	validation_0-rmse:0.28896
# [417]	validation_0-rmse:0.28896
# [418]	validation_0-rmse:0.28896
# [419]	validation_0-rmse:0.28896
# [420]	validation_0-rmse:0.28896
# [421]	validation_0-rmse:0.28896
# [422]	validation_0-rmse:0.28896
# [423]	validation_0-rmse:0.28896
# [424]	validation_0-rmse:0.28896
# [425]	validation_0-rmse:0.28896
# [426]	validation_0-rmse:0.28896
# [427]	validation_0-rmse:0.28896
# [428]	validation_0-rmse:0.28896
# [429]	validation_0-rmse:0.28896
# [430]	validation_0-rmse:0.28896
# [431]	validation_0-rmse:0.28896
# [432]	validation_0-rmse:0.28896
# [433]	validation_0-rmse:0.28896
# [434]	validation_0-rmse:0.28896
# [435]	validation_0-rmse:0.28896
# [436]	validation_0-rmse:0.28896
# [437]	validation_0-rmse:0.28896
# [438]	validation_0-rmse:0.28896
# [439]	validation_0-rmse:0.28896
# [440]	validation_0-rmse:0.28896
# [441]	validation_0-rmse:0.28896
# [442]	validation_0-rmse:0.28896
# [443]	validation_0-rmse:0.28896
# [444]	validation_0-rmse:0.28896
# [445]	validation_0-rmse:0.28896
# [446]	validation_0-rmse:0.28896
# [447]	validation_0-rmse:0.28896
# [448]	validation_0-rmse:0.28896
# [449]	validation_0-rmse:0.28896
# [450]	validation_0-rmse:0.28896
# [451]	validation_0-rmse:0.28896
# [452]	validation_0-rmse:0.28896
# [453]	validation_0-rmse:0.28896
# [454]	validation_0-rmse:0.28896
# [455]	validation_0-rmse:0.28896
# [456]	validation_0-rmse:0.28896
# [457]	validation_0-rmse:0.28896
# [458]	validation_0-rmse:0.28896
# [459]	validation_0-rmse:0.28896
# [460]	validation_0-rmse:0.28896
# [461]	validation_0-rmse:0.28896
# [462]	validation_0-rmse:0.28896
# [783]	validation_0-rmse:0.28894
# [784]	validation_0-rmse:0.28894
# [785]	validation_0-rmse:0.28894
# [786]	validation_0-rmse:0.28894
# [787]	validation_0-rmse:0.28894
# [788]	validation_0-rmse:0.28894
# [789]	validation_0-rmse:0.28894
# [790]	validation_0-rmse:0.28894
# [791]	validation_0-rmse:0.28894
# [792]	validation_0-rmse:0.28894
# [793]	validation_0-rmse:0.28894
# [794]	validation_0-rmse:0.28894
# [795]	validation_0-rmse:0.28894
# [796]	validation_0-rmse:0.28894
# [797]	validation_0-rmse:0.28894
# [798]	validation_0-rmse:0.28894
# [799]	validation_0-rmse:0.28894
# [800]	validation_0-rmse:0.28894
# [801]	validation_0-rmse:0.28894
# [802]	validation_0-rmse:0.28894
# [803]	validation_0-rmse:0.28894
# [804]	validation_0-rmse:0.28894
# [805]	validation_0-rmse:0.28894
# [806]	validation_0-rmse:0.28894
# [807]	validation_0-rmse:0.28894
# [808]	validation_0-rmse:0.28894
# [809]	validation_0-rmse:0.28894
# [810]	validation_0-rmse:0.28894
# [811]	validation_0-rmse:0.28894
# [812]	validation_0-rmse:0.28894
# [813]	validation_0-rmse:0.28894
# [814]	validation_0-rmse:0.28894
# [815]	validation_0-rmse:0.28894
# [816]	validation_0-rmse:0.28894
# [817]	validation_0-rmse:0.28894
# [818]	validation_0-rmse:0.28894
# [819]	validation_0-rmse:0.28894
# [820]	validation_0-rmse:0.28894
# [821]	validation_0-rmse:0.28894
# [822]	validation_0-rmse:0.28894
# [823]	validation_0-rmse:0.28894
# [824]	validation_0-rmse:0.28894
# [825]	validation_0-rmse:0.28894
# [826]	validation_0-rmse:0.28894
# [827]	validation_0-rmse:0.28894
# [828]	validation_0-rmse:0.28894
# [829]	validation_0-rmse:0.28894
# [830]	validation_0-rmse:0.28894
# [831]	validation_0-rmse:0.28894
# [832]	validation_0-rmse:0.28894
# [833]	validation_0-rmse:0.28894
# [834]	validation_0-rmse:0.28894
# [835]	validation_0-rmse:0.28894
# [836]	validation_0-rmse:0.28894
# [837]	validation_0-rmse:0.28894
# [838]	validation_0-rmse:0.28894
# [839]	validation_0-rmse:0.28894
# [840]	validation_0-rmse:0.28894
# [841]	validation_0-rmse:0.28894
# [842]	validation_0-rmse:0.28894
# [843]	validation_0-rmse:0.28894
# [844]	validation_0-rmse:0.28894
# [845]	validation_0-rmse:0.28894
# [846]	validation_0-rmse:0.28894
# [847]	validation_0-rmse:0.28894
# [848]	validation_0-rmse:0.28894
# [849]	validation_0-rmse:0.28894
# [850]	validation_0-rmse:0.28894
# [851]	validation_0-rmse:0.28894
# [852]	validation_0-rmse:0.28894
# [853]	validation_0-rmse:0.28894
# [854]	validation_0-rmse:0.28894
# [855]	validation_0-rmse:0.28894
# [856]	validation_0-rmse:0.28894
# [857]	validation_0-rmse:0.28894
# [858]	validation_0-rmse:0.28894
# [859]	validation_0-rmse:0.28894
# [860]	validation_0-rmse:0.28894
# [861]	validation_0-rmse:0.28894
# [862]	validation_0-rmse:0.28894
# [863]	validation_0-rmse:0.28894
# [864]	validation_0-rmse:0.28894
# [865]	validation_0-rmse:0.28894
# [866]	validation_0-rmse:0.28894
# [867]	validation_0-rmse:0.28894
# [868]	validation_0-rmse:0.28894
# [869]	validation_0-rmse:0.28894
# [870]	validation_0-rmse:0.28894
# [871]	validation_0-rmse:0.28894
# [872]	validation_0-rmse:0.28894
# [873]	validation_0-rmse:0.28894
# [874]	validation_0-rmse:0.28894
# [875]	validation_0-rmse:0.28894
# [876]	validation_0-rmse:0.28894
# [877]	validation_0-rmse:0.28894
# [878]	validation_0-rmse:0.28894
# [879]	validation_0-rmse:0.28894
# [880]	validation_0-rmse:0.28894
# [881]	validation_0-rmse:0.28894
# [882]	validation_0-rmse:0.28894
# [883]	validation_0-rmse:0.28894
# [884]	validation_0-rmse:0.28894
# [885]	validation_0-rmse:0.28894
# [886]	validation_0-rmse:0.28894
# [887]	validation_0-rmse:0.28894
# [888]	validation_0-rmse:0.28894
# [889]	validation_0-rmse:0.28894
# [890]	validation_0-rmse:0.28894
# [891]	validation_0-rmse:0.28894
# [892]	validation_0-rmse:0.28894
# [893]	validation_0-rmse:0.28894
# [894]	validation_0-rmse:0.28894
# [895]	validation_0-rmse:0.28894
# [896]	validation_0-rmse:0.28894
# [897]	validation_0-rmse:0.28894
# [898]	validation_0-rmse:0.28894
# [899]	validation_0-rmse:0.28894
# [900]	validation_0-rmse:0.28894
# [901]	validation_0-rmse:0.28894
# [902]	validation_0-rmse:0.28894
# [903]	validation_0-rmse:0.28894
# [904]	validation_0-rmse:0.28894
# [905]	validation_0-rmse:0.28894
# [906]	validation_0-rmse:0.28894
# [907]	validation_0-rmse:0.28894
# [908]	validation_0-rmse:0.28894
# [909]	validation_0-rmse:0.28894
# [910]	validation_0-rmse:0.28894
# [911]	validation_0-rmse:0.28894
# [912]	validation_0-rmse:0.28894
# [913]	validation_0-rmse:0.28894
# [914]	validation_0-rmse:0.28894
# [915]	validation_0-rmse:0.28894
# [916]	validation_0-rmse:0.28894
# [917]	validation_0-rmse:0.28894
# [918]	validation_0-rmse:0.28894
# [919]	validation_0-rmse:0.28894
# [920]	validation_0-rmse:0.28894
# [921]	validation_0-rmse:0.28894
# [922]	validation_0-rmse:0.28894
# [923]	validation_0-rmse:0.28894
# [924]	validation_0-rmse:0.28894
# [925]	validation_0-rmse:0.28894
# [926]	validation_0-rmse:0.28894
# [927]	validation_0-rmse:0.28894
# [928]	validation_0-rmse:0.28894
# [929]	validation_0-rmse:0.28894
# [930]	validation_0-rmse:0.28894
# [931]	validation_0-rmse:0.28894
# [932]	validation_0-rmse:0.28894
# [933]	validation_0-rmse:0.28894
# [934]	validation_0-rmse:0.28894
# [935]	validation_0-rmse:0.28894
# [936]	validation_0-rmse:0.28894
# [937]	validation_0-rmse:0.28894
# [938]	validation_0-rmse:0.28894
# [939]	validation_0-rmse:0.28894
# [940]	validation_0-rmse:0.28894
# [941]	validation_0-rmse:0.28894
# [942]	validation_0-rmse:0.28894
# [943]	validation_0-rmse:0.28894
# [944]	validation_0-rmse:0.28894
# [945]	validation_0-rmse:0.28894
# [946]	validation_0-rmse:0.28894
# [947]	validation_0-rmse:0.28894
# [948]	validation_0-rmse:0.28894
# [949]	validation_0-rmse:0.28894
# [950]	validation_0-rmse:0.28894
# [951]	validation_0-rmse:0.28894
# [952]	validation_0-rmse:0.28894
# [953]	validation_0-rmse:0.28894
# [954]	validation_0-rmse:0.28894
# [955]	validation_0-rmse:0.28894
# [956]	validation_0-rmse:0.28894
# [957]	validation_0-rmse:0.28894
# [958]	validation_0-rmse:0.28894
# [959]	validation_0-rmse:0.28894
# [960]	validation_0-rmse:0.28894
# [961]	validation_0-rmse:0.28894
# [962]	validation_0-rmse:0.28894
# [963]	validation_0-rmse:0.28894
# [964]	validation_0-rmse:0.28894
# [965]	validation_0-rmse:0.28894
# [966]	validation_0-rmse:0.28894
# [967]	validation_0-rmse:0.28894
# [968]	validation_0-rmse:0.28894
# [969]	validation_0-rmse:0.28894
# [970]	validation_0-rmse:0.28894
# [971]	validation_0-rmse:0.28894
# [972]	validation_0-rmse:0.28894
# [973]	validation_0-rmse:0.28894
# [974]	validation_0-rmse:0.28894
# [975]	validation_0-rmse:0.28894
# [976]	validation_0-rmse:0.28894
# [977]	validation_0-rmse:0.28894
# [978]	validation_0-rmse:0.28894
# [979]	validation_0-rmse:0.28894
# [980]	validation_0-rmse:0.28894
# [981]	validation_0-rmse:0.28894
# [982]	validation_0-rmse:0.28894
# [983]	validation_0-rmse:0.28894
# [984]	validation_0-rmse:0.28894
# [985]	validation_0-rmse:0.28894
# [986]	validation_0-rmse:0.28894
# [987]	validation_0-rmse:0.28894
# [988]	validation_0-rmse:0.28894
# [989]	validation_0-rmse:0.28894
# [990]	validation_0-rmse:0.28894
# [991]	validation_0-rmse:0.28894
# [992]	validation_0-rmse:0.28894
# [993]	validation_0-rmse:0.28894
# [994]	validation_0-rmse:0.28894
# [995]	validation_0-rmse:0.28894
# [996]	validation_0-rmse:0.28894
# [997]	validation_0-rmse:0.28894
# [998]	validation_0-rmse:0.28894
# [999]	validation_0-rmse:0.28894
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=True, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=1000, n_jobs=-1,
#              num_parallel_tree=None, random_state=None, ...)

# %%
xgb.fit(train_x_n, train_y_n, eval_set=[(train_x_n2[:300_000], train_y_n2[:300_000])], verbose=True)
# Out:
# [0]	validation_0-rmse:0.28837
# [1]	validation_0-rmse:0.28837
# [2]	validation_0-rmse:0.28836
# [3]	validation_0-rmse:0.28836
# [4]	validation_0-rmse:0.28836
# [5]	validation_0-rmse:0.28835
# [6]	validation_0-rmse:0.28835
# [7]	validation_0-rmse:0.28835
# [8]	validation_0-rmse:0.28834
# [9]	validation_0-rmse:0.28834
# [10]	validation_0-rmse:0.28834
# [11]	validation_0-rmse:0.28833
# [12]	validation_0-rmse:0.28833
# [13]	validation_0-rmse:0.28833
# [14]	validation_0-rmse:0.28833
# [15]	validation_0-rmse:0.28832
# [16]	validation_0-rmse:0.28832
# [17]	validation_0-rmse:0.28832
# [18]	validation_0-rmse:0.28831
# [19]	validation_0-rmse:0.28831
# [20]	validation_0-rmse:0.28831
# [21]	validation_0-rmse:0.28831
# [22]	validation_0-rmse:0.28830
# [23]	validation_0-rmse:0.28830
# [24]	validation_0-rmse:0.28830
# [25]	validation_0-rmse:0.28830
# [26]	validation_0-rmse:0.28829
# [27]	validation_0-rmse:0.28829
# [28]	validation_0-rmse:0.28829
# [29]	validation_0-rmse:0.28829
# [30]	validation_0-rmse:0.28828
# [31]	validation_0-rmse:0.28828
# [32]	validation_0-rmse:0.28828
# [33]	validation_0-rmse:0.28828
# [34]	validation_0-rmse:0.28828
# [35]	validation_0-rmse:0.28827
# [36]	validation_0-rmse:0.28827
# [37]	validation_0-rmse:0.28827
# [38]	validation_0-rmse:0.28827
# [39]	validation_0-rmse:0.28826
# [40]	validation_0-rmse:0.28826
# [41]	validation_0-rmse:0.28826
# [42]	validation_0-rmse:0.28826
# [43]	validation_0-rmse:0.28826
# [44]	validation_0-rmse:0.28826
# [45]	validation_0-rmse:0.28825
# [46]	validation_0-rmse:0.28825
# [47]	validation_0-rmse:0.28825
# [48]	validation_0-rmse:0.28825
# [49]	validation_0-rmse:0.28825
# [50]	validation_0-rmse:0.28824
# [51]	validation_0-rmse:0.28824
# [52]	validation_0-rmse:0.28824
# [53]	validation_0-rmse:0.28824
# [54]	validation_0-rmse:0.28824
# [55]	validation_0-rmse:0.28824
# [56]	validation_0-rmse:0.28824
# [57]	validation_0-rmse:0.28823
# [58]	validation_0-rmse:0.28823
# [59]	validation_0-rmse:0.28823
# [60]	validation_0-rmse:0.28823
# [61]	validation_0-rmse:0.28823
# [62]	validation_0-rmse:0.28823
# [63]	validation_0-rmse:0.28823
# [64]	validation_0-rmse:0.28822
# [65]	validation_0-rmse:0.28822
# [66]	validation_0-rmse:0.28822
# [67]	validation_0-rmse:0.28822
# [68]	validation_0-rmse:0.28822
# [69]	validation_0-rmse:0.28822
# [70]	validation_0-rmse:0.28822
# [71]	validation_0-rmse:0.28821
# [72]	validation_0-rmse:0.28821
# [73]	validation_0-rmse:0.28821
# [74]	validation_0-rmse:0.28821
# [75]	validation_0-rmse:0.28821
# [76]	validation_0-rmse:0.28821
# [77]	validation_0-rmse:0.28821
# [78]	validation_0-rmse:0.28821
# [79]	validation_0-rmse:0.28820
# [80]	validation_0-rmse:0.28820
# [81]	validation_0-rmse:0.28820
# [82]	validation_0-rmse:0.28820
# [83]	validation_0-rmse:0.28820
# [84]	validation_0-rmse:0.28820
# [85]	validation_0-rmse:0.28820
# [86]	validation_0-rmse:0.28820
# [87]	validation_0-rmse:0.28820
# [88]	validation_0-rmse:0.28819
# [89]	validation_0-rmse:0.28819
# [90]	validation_0-rmse:0.28819
# [91]	validation_0-rmse:0.28819
# [92]	validation_0-rmse:0.28819
# [93]	validation_0-rmse:0.28819
# [94]	validation_0-rmse:0.28819
# [95]	validation_0-rmse:0.28819
# [96]	validation_0-rmse:0.28819
# [97]	validation_0-rmse:0.28819
# [98]	validation_0-rmse:0.28819
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 xgb.fit(train_x_n2, train_y_n2, eval_set=[(train_x_n2[:300_000], train_y_n2[:300_000])], verbose=True)
#
# File c:\Users\foler\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:726, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     724 for k, arg in zip(sig.parameters, args):
#     725     kwargs[k] = arg
# --> 726 return func(**kwargs)
#
# File c:\Users\foler\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\sklearn.py:1108, in XGBModel.fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1105     obj = None
#    1107 model, metric, params = self._configure_fit(xgb_model, params)
# -> 1108 self._Booster = train(
#    1109     params,
#    1110     train_dmatrix,
#    1111     self.get_num_boosting_rounds(),
#    1112     evals=evals,
#    1113     early_stopping_rounds=self.early_stopping_rounds,
#    1114     evals_result=evals_result,
#    1115     obj=obj,
#    1116     custom_metric=metric,
#    1117     verbose_eval=verbose,
#    1118     xgb_model=model,
#    1119     callbacks=self.callbacks,
#    1120 )
#    1122 self._set_evaluation_result(evals_result)
#    1123 return self
#
# File c:\Users\foler\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:726, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     724 for k, arg in zip(sig.parameters, args):
#     725     kwargs[k] = arg
# --> 726 return func(**kwargs)
#
# File c:\Users\foler\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\training.py:181, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     179 if cb_container.before_iteration(bst, i, dtrain, evals):
#     180     break
# --> 181 bst.update(dtrain, iteration=i, fobj=obj)
#     182 if cb_container.after_iteration(bst, i, dtrain, evals):
#     183     break
#
# File c:\Users\foler\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:2101, in Booster.update(self, dtrain, iteration, fobj)
#    2097 self._assign_dmatrix_features(dtrain)
#    2099 if fobj is None:
#    2100     _check_call(
# -> 2101         _LIB.XGBoosterUpdateOneIter(
#    2102             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2103         )
#    2104     )
#    2105 else:
#    2106     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %%
rfr = RandomForestRegressor(
    n_estimators=100,
    n_jobs=-1,
)

# %%
train_y_n2["Price"].array.astype(float)
# Out:
# array([0.73415319, 0.84999793, 0.04721259, ..., 0.98655333, 0.05424215,
#        0.68601474], shape=(3694318,))

# %%
rfr.fit(train_x_n, train_y_n["Price"].array.astype(float))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\foler\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\arrays\categorical.py:591, in Categorical.astype(self, dtype, copy)
#     590 try:
# --> 591     new_cats = new_cats.astype(dtype=dtype, copy=copy)
#     592     fill_value = self.categories._na_value
#
# ValueError: could not convert string to float: 'Black'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[154], line 1
# ----> 1 rfr.fit(train_x_n, train_y_n["Price"].array.astype(float))
#
# File c:\Users\foler\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\foler\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\ensemble\_forest.py:363, in BaseForest.fit(self, X, y, sample_weight)
#     360 if issparse(y):
#     361     raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 363 X, y = self._validate_data(
#     364     X,
#     365     y,
#     366     multi_output=True,
#     367     accept_sparse="csc",
#     368     dtype=DTYPE,
#     369     force_all_finite=False,
#     370 )
#     371 # _compute_missing_values_in_feature_mask checks if X has missing values and
#     372 # will raise an error if the underlying tree base estimator can't handle missing
#     373 # values. Only the criterion is required to determine if the tree supports
#     374 # missing values.
#     375 estimator = type(self.estimator)(criterion=self.criterion)
#
# File c:\Users\foler\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:650, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     648         y = check_array(y, input_name="y", **check_y_params)
#     649     else:
# --> 650         X, y = check_X_y(X, y, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
#
# File c:\Users\foler\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1301, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1296         estimator_name = _check_estimator_name(estimator)
#    1297     raise ValueError(
#    1298         f"{estimator_name} requires y to be passed, but the target y is None"
#    1299     )
# -> 1301 X = check_array(
#    1302     X,
#    1303     accept_sparse=accept_sparse,
#    1304     accept_large_sparse=accept_large_sparse,
#    1305     dtype=dtype,
#    1306     order=order,
#    1307     copy=copy,
#    1308     force_writeable=force_writeable,
#    1309     force_all_finite=force_all_finite,
#    1310     ensure_2d=ensure_2d,
#    1311     allow_nd=allow_nd,
#    1312     ensure_min_samples=ensure_min_samples,
#    1313     ensure_min_features=ensure_min_features,
#    1314     estimator=estimator,
#    1315     input_name="X",
#    1316 )
#    1318 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1320 check_consistent_length(X, y)
#
# File c:\Users\foler\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:929, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     924 if pandas_requires_conversion:
#     925     # pandas dataframe requires conversion earlier to handle extension dtypes with
#     926     # nans
#     927     # Use the original dtype for conversion if dtype is None
#     928     new_dtype = dtype_orig if dtype is None else dtype
# --> 929     array = array.astype(new_dtype)
#     930     # Since we converted here, we do not need to convert again later
#     931     dtype = None
#
# File c:\Users\foler\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File c:\Users\foler\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
#     432     dtype=dtype,
#     433     copy=copy,
#     434     errors=errors,
#     435     using_cow=using_copy_on_write(),
#     436 )
#
# File c:\Users\foler\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File c:\Users\foler\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\blocks.py:758, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     755         raise ValueError("Can not squeeze with more than one column.")
#     756     values = values[0, :]  # type: ignore[call-overload]
# --> 758 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     760 new_values = maybe_coerce_values(new_values)
#     762 refs = None
#
# File c:\Users\foler\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\dtypes\astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File c:\Users\foler\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\dtypes\astype.py:179, in astype_array(values, dtype, copy)
#     175     return values
#     177 if not isinstance(values, np.ndarray):
#     178     # i.e. ExtensionArray
# --> 179     values = values.astype(dtype, copy=copy)
#     181 else:
#     182     values = _astype_nansafe(values, dtype, copy=copy)
#
# File c:\Users\foler\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\arrays\categorical.py:602, in Categorical.astype(self, dtype, copy)
#     597     except (
#     598         TypeError,  # downstream error msg for CategoricalIndex is misleading
#     599         ValueError,
#     600     ):
#     601         msg = f"Cannot cast {self.categories.dtype} dtype to {dtype}"
# --> 602         raise ValueError(msg)
#     604     result = take_nd(
#     605         new_cats, ensure_platform_int(self._codes), fill_value=fill_value
#     606     )
#     608 return result
#
# ValueError: Cannot cast object dtype to float32

# %%
from sklearn.metrics import root_mean_squared_error as RMSE

def Score(model, _df: pd.DataFrame, df_func = make_df):
    df = df_func(_df)

    df_x, df_y = get_xy(df, ["Price"])

    df_x_n = normalize(df_x)
    df_y_n = normalize(df_y)

    predict = model.predict(df_x_n) * 150
    return RMSE(df_y, predict)#, model.score(df_x_n, df_y_n)

# %%
Score(xgb, train_df)
# Out:
# (np.float64(39.765601684345185), 0.0016442537307739258)

# %%
Score(xgb, training_extra_df)
# Out:
# (np.float64(39.66071046120994), -2.765655517578125e-05)

# %%
def CalcY(model, _df: pd.DataFrame, df_func = make_df) -> pd.array:
    df_x = df_func(_df)
    df_x_n = normalize(df_x)
    return model.predict(df_x_n) * 150

# %%
def SaveCalcY(model, _df: pd.DataFrame, start=0, df_func = make_df):
    y = CalcY(model, _df, df_func)
    y_df = pd.DataFrame(y, index=range(start, start + len(y)))
    y_df = y_df.rename(columns={0: "Price"})
    y_df.to_csv(f"submission_{str(model.__class__.__name__)}.csv", index_label="id")

# %%
SaveCalcY(xgb, test_df, len(train_df))

# %%
SaveCalcY(rfr, test_df, len(train_df))

# %%
import keras
from keras import Sequential
from keras.layers import Dense, Input, Reshape, Conv2D, Conv2DTranspose, Flatten, MaxPool2D, Dropout

# %%
dim = 16

# model = Sequential([
#     Dense(1000, activation="relu"),
#     Dense(128, activation="relu"),
#     Dense(1, activation="sigmoid")
# ])

model = Sequential([
    Input((len( train_x_n.columns ),) ),
    Dense(dim ** 3, activation="relu"),
    Reshape((dim,) * 3),
    Conv2D(3, 3, 2, padding="same"),
    Conv2DTranspose(3, 3, 2, padding="same"),
    Flatten(),
    Dense(1, activation="sigmoid")
])

model.compile(
    optimizer="nadam",
    loss=keras.losses.mean_squared_error
)

# %%
model.summary()
# Out:
# Model: "sequential_35"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_104 (Dense)               │ (None, 4096)           │       106,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_21 (Reshape)            │ (None, 16, 16, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_19 (Conv2D)              │ (None, 8, 8, 3)        │           435 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_11             │ (None, 16, 16, 3)      │            84 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_10 (Flatten)            │ (None, 768)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_105 (Dense)               │ (None, 1)              │           769 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 107,784 (421.03 KB)
#  Trainable params: 107,784 (421.03 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(train_x_n, train_y_n, batch_size=32, epochs=10, validation_data=(train_x_n2[:100_000], train_y_n2[:100_000]))
# Out:
# Epoch 1/10
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 29s 3ms/step - loss: 0.0834 - val_loss: 0.0829
# Epoch 2/10
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 31s 3ms/step - loss: 0.0833 - val_loss: 0.0832
# Epoch 3/10
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 29s 3ms/step - loss: 0.0832 - val_loss: 0.0829
# Epoch 4/10
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 42s 3ms/step - loss: 0.0832 - val_loss: 0.0829
# Epoch 5/10
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 26s 3ms/step - loss: 0.0833 - val_loss: 0.0831
# Epoch 6/10
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 30s 3ms/step - loss: 0.0830 - val_loss: 0.0830
# Epoch 7/10
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 29s 3ms/step - loss: 0.0834 - val_loss: 0.0830
# Epoch 8/10
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 28s 3ms/step - loss: 0.0835 - val_loss: 0.0830
# Epoch 9/10
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 27s 3ms/step - loss: 0.0833 - val_loss: 0.0831
# Epoch 10/10
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 27s 3ms/step - loss: 0.0831 - val_loss: 0.0831

# %%
Score(model, train_df, make_df_with_one_hot)
# Out:
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 13s 1ms/step
# 39.695945739746094

# %%
SaveCalcY(model, test_df, len(train_df), make_df_with_one_hot)
# Out:
# 6250/6250 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
