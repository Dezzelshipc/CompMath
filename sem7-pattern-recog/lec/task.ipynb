# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
pic = cv2.imread("./XMCD#0000.JPG", cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(pic, cmap="gray")

# %%
pic2 = pic.copy()

cut = (60, 175)

pic2[pic2 < cut[0]] = 0
pic2[pic2 > cut[1]] = 255

# c3 = np.where(cut[0] < pic2, np.where(pic2 < cut[1], True, False), False)

c3 = (cut[0] < pic2) & (pic2 < cut[1])

pic2[c3] = 128

plt.imshow(pic2, cmap="gray")

plt.plot([0, 1000], [1000-100, 1000-100])
